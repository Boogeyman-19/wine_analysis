# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns


from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
wine=pd.read_csv(r'C:\Users\reddy\OneDrive\Desktop\Major Project Dataset (Wine Classification).csv')
wine.sample(25)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1380            7.5             0.570         0.02             2.6      0.077
# 705             8.4             1.035         0.15             6.0      0.073
# 886             9.0             0.800         0.12             2.4      0.083
# 547            10.6             0.310         0.49             2.5      0.067
# 1187            7.0             0.430         0.30             2.0      0.085
# 184             6.7             0.620         0.21             1.9      0.079
# 684             9.8             0.980         0.32             2.3      0.078
# 473             9.9             0.350         0.55             2.1      0.062
# 679            10.8             0.260         0.45             3.3      0.060
# 173             7.4             0.620         0.05             1.9      0.068
# 523             9.3             0.400         0.49             2.5      0.085
# 201             8.8             0.370         0.48             2.1      0.097
# 109             8.1             0.785         0.52             2.0      0.122
# 55              7.7             0.620         0.04             3.8      0.084
# 745             7.3             0.510         0.18             2.1      0.070
# 424             7.7             0.960         0.20             2.0      0.047
# 1512            6.4             0.790         0.04             2.2      0.061
# 214             7.8             0.735         0.08             2.4      0.092
# 1577            6.2             0.700         0.15             5.1      0.076
# 1389            6.7             0.480         0.02             2.2      0.080
# 348             9.6             0.560         0.31             2.8      0.089
# 1313            7.0             0.360         0.21             2.3      0.086
# 1395            8.6             0.685         0.10             1.6      0.092
# 1526            6.8             0.470         0.08             2.2      0.064
# 450            11.9             0.390         0.69             2.8      0.095
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1380                 11.0                  35.0  0.99557  3.52       0.62
# 705                  11.0                  54.0  0.99900  3.52       0.49
# 886                   8.0                  28.0  0.99836  3.52       0.65
# 547                   6.0                  21.0  0.99870  3.52       0.86
# 1187                  6.0                  39.0  0.99346  3.52       0.46
# 184                   8.0                  62.0  0.99700   NaN       0.58
# 684                  35.0                 152.0  0.99800  3.52       0.48
# 473                   5.0                  14.0  0.99710  3.52       0.79
# 679                  20.0                  49.0  0.99720  3.52       0.54
# 173                  24.0                  42.0  0.99610  3.42       0.57
# 523                  38.0                 142.0  0.99780  3.52       0.55
# 201                  39.0                 145.0  0.99750  3.52       1.03
# 109                  37.0                 153.0  0.99690  3.21       0.69
# 55                   25.0                  45.0  0.99780  3.34       0.53
# 745                  12.0                  28.0  0.99768  3.52       0.73
# 424                  15.0                  60.0  0.99550  3.52       0.44
# 1512                 11.0                  17.0  0.99588  3.52       0.65
# 214                  10.0                  41.0  0.99740  3.52       0.71
# 1577                 13.0                  27.0  0.99622  3.52       0.60
# 1389                 36.0                 111.0  0.99524  3.52       0.53
# 348                  15.0                  46.0  0.99790  3.52       0.92
# 1313                 20.0                  65.0  0.99558  3.52       0.54
# 1395                  3.0                  12.0  0.99745  3.52       0.65
# 1526                 18.0                  38.0  0.99553  3.52       0.65
# 450                  17.0                  35.0  0.99940  3.52       0.61
#
#       alcohol  quality
# 1380    10.80      6.0
# 705      9.90      5.0
# 886     10.40      6.0
# 547     10.70      6.0
# 1187    11.90      6.0
# 184      9.30      6.0
# 684      9.40      5.0
# 473     10.60      5.0
# 679      9.60      5.0
# 173     11.50      6.0
# 523      9.40      5.0
# 201      9.30      5.0
# 109      9.30      5.0
# 55       9.50      5.0
# 745      9.50      6.0
# 424     10.90      5.0
# 1512    10.40      6.0
# 214      9.80      6.0
# 1577    11.90      6.0
# 1389     9.70      5.0
# 348     10.00      6.0
# 1313    10.10      6.0
# 1395     9.55      6.0
# 1526     9.60      6.0
# 450     10.80      6.0

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1598.000000  1599.000000
# mean      0.087467            15.874922             46.433041     0.996747
# std       0.047065            10.460157             32.876249     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1598.000000  1599.000000  1599.000000  1598.000000
# mean      3.498586     0.658149    10.422983     5.636421
# std       0.080346     0.169507     1.065668     0.807665
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.520000     0.550000     9.500000     5.000000
# 50%       3.520000     0.620000    10.200000     6.000000
# 75%       3.520000     0.730000    11.100000     6.000000
# max       3.900000     2.000000    14.900000     8.000000

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    1
# density                 0
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
for col, value in wine.items():
    if col != 'type':
        wine[col] = wine[col].fillna(wine[col].mean())

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine.groupby('quality').mean()
# Out:
#           fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3.000000       8.360000          0.884500     0.171000        2.635000
# 4.000000       7.779245          0.693962     0.174151        2.694340
# 5.000000       8.167500          0.576846     0.244044        2.528750
# 5.636421       8.000000          0.710000     0.000000        2.600000
# 6.000000       8.347179          0.497484     0.273824        2.477194
# 7.000000       8.872362          0.403920     0.375176        2.720603
# 8.000000       8.566667          0.423333     0.391111        2.577778
#
#           chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3.000000   0.122500            11.000000             24.900000  0.997464
# 4.000000   0.090679            12.264151             36.245283  0.996542
# 5.000000   0.092754            16.992647             56.465343  0.997103
# 5.636421   0.080000            11.000000             34.000000  0.997600
# 6.000000   0.084956            15.711599             40.869906  0.996615
# 7.000000   0.076588            14.045226             35.020101  0.996104
# 8.000000   0.068444            13.277778             33.444444  0.995212
#
#                 pH  sulphates    alcohol
# quality
# 3.000000  3.520000   0.570000   9.955000
# 4.000000  3.485660   0.596415  10.265094
# 5.000000  3.485147   0.621103   9.900294
# 5.636421  3.440000   0.530000   9.500000
# 6.000000  3.508086   0.675329  10.629519
# 7.000000  3.514774   0.741256  11.465913
# 8.000000  3.520000   0.767778  12.094444

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in wine.items():
    if col != 'type':
        sns.boxplot(y=col, data=wine, ax=ax[index])
        index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in wine.items():
    if col != 'type':
        sns.distplot(value, ax=ax[index])
        index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
sns.countplot(wine['quality'])
plt.show()

# %%
wine.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# fixed acidity              Axes(0.125,0.712609;0.168478x0.167391)
# volatile acidity        Axes(0.327174,0.712609;0.168478x0.167391)
# citric acid             Axes(0.529348,0.712609;0.168478x0.167391)
# residual sugar          Axes(0.731522,0.712609;0.168478x0.167391)
# chlorides                  Axes(0.125,0.511739;0.168478x0.167391)
# free sulfur dioxide     Axes(0.327174,0.511739;0.168478x0.167391)
# total sulfur dioxide    Axes(0.529348,0.511739;0.168478x0.167391)
# density                 Axes(0.731522,0.511739;0.168478x0.167391)
# pH                          Axes(0.125,0.31087;0.168478x0.167391)
# sulphates                Axes(0.327174,0.31087;0.168478x0.167391)
# alcohol                  Axes(0.529348,0.31087;0.168478x0.167391)
# quality                  Axes(0.731522,0.31087;0.168478x0.167391)
# dtype: object

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='fixed acidity', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='volatile acidity', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='citric acid', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='residual sugar', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='chlorides', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='free sulfur dioxide', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='total sulfur dioxide', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='density', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='pH', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='sulphates', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
plt.figure(figsize =(10,6))
sns.barplot(x='quality', y='alcohol', data=wine)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
wine['fixed acidity'].plot(kind ='box')
# Out:
# <Axes: >

# %%
wine.hist(figsize=(10,10),bins=50)
plt.show()

# %%
wine.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 272            10.9             0.370         0.58             4.0      0.071
# 1437            6.8             0.915         0.29             4.8      0.070
# 694             9.0             0.470         0.31             2.7      0.084
# 1097            8.6             0.520         0.38             1.5      0.096
# 611            13.2             0.380         0.55             2.7      0.081
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 272                  17.0                  65.0  0.99935  3.52       0.78
# 1437                 15.0                  39.0  0.99577  3.52       0.54
# 694                  24.0                 125.0  0.99840  3.52       0.61
# 1097                  5.0                  18.0  0.99666  3.52       0.52
# 611                   5.0                  16.0  1.00060  3.52       0.54
#
#       alcohol  quality
# 272      10.1      5.0
# 1437     11.1      5.0
# 694       9.4      5.0
# 1097      9.4      5.0
# 611       9.4      5.0

# %%
wine['quality'].unique()
# Out:
# array([5.        , 6.        , 7.        , 4.        , 5.63642053,
#        8.        , 3.        ])

# %%
wine['goodquality'] = [1 if x >= 7 else 0 for x in wine['quality']]
wine.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 128             8.0              0.59         0.16             1.8      0.065
# 661             7.5              0.42         0.31             1.6      0.080
# 152             7.5              0.60         0.03             1.8      0.095
# 1480            5.6              0.62         0.03             1.5      0.080
# 1398            7.0              0.60         0.12             2.2      0.083
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 128                   3.0                  16.0  0.99620  3.42       0.92
# 661                  15.0                  42.0  0.99780  3.52       0.64
# 152                  25.0                  99.0  0.99500  3.35       0.54
# 1480                  6.0                  13.0  0.99498  3.52       0.62
# 1398                 13.0                  28.0  0.99660  3.52       0.62
#
#       alcohol  quality  goodquality
# 128      10.5      7.0            1
# 661       9.0      5.0            0
# 152      10.1      5.0            0
# 1480     10.1      4.0            0
# 1398     10.2      7.0            1

# %%
wine['goodquality'].value_counts()
# Out:
# goodquality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %%
X = wine.drop(['quality','goodquality'], axis = 1)
Y = wine['goodquality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.52       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.52       0.75
# 1597                 32.0                  44.0  0.99547  3.52       0.71
# 1598                 18.0                  42.0  0.99549  3.52       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: goodquality, Length: 1599, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(X,Y)
score = classifiern.feature_importances_
print(score)
# Out:
# [0.08585278 0.10702459 0.10139861 0.08073635 0.0747937  0.07350083
#  0.08850332 0.08909761 0.01193848 0.11419876 0.17295497]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %%
model_res=pd.DataFrame(columns=['Model', 'Score'])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
# accuracy_score(Y_test,Y_pred)
model_res.loc[len(model_res)] = ['LogisticRegression', accuracy_score(Y_test,y_pred)]
model_res
# Out:
#                 Model  Score
# 0  LogisticRegression  0.875

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
model_res.loc[len(model_res)] = ['KNeighborsClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
#                   Model     Score
# 0    LogisticRegression  0.875000
# 1  KNeighborsClassifier  0.872917

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['SVC', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.86875
#                   Model     Score
# 0    LogisticRegression  0.875000
# 1  KNeighborsClassifier  0.872917
# 2                   SVC  0.868750

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['DecisionTreeClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.8604166666666667
#                     Model     Score
# 0      LogisticRegression  0.875000
# 1    KNeighborsClassifier  0.872917
# 2                     SVC  0.868750
# 3  DecisionTreeClassifier  0.860417

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['GaussianNB', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.7541666666666667
#                     Model     Score
# 0      LogisticRegression  0.875000
# 1    KNeighborsClassifier  0.872917
# 2                     SVC  0.868750
# 3  DecisionTreeClassifier  0.860417
# 4              GaussianNB  0.754167

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['RandomForestClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.8958333333333334
#                     Model     Score
# 0      LogisticRegression  0.875000
# 1    KNeighborsClassifier  0.872917
# 2                     SVC  0.868750
# 3  DecisionTreeClassifier  0.860417
# 4              GaussianNB  0.754167
# 5  RandomForestClassifier  0.895833

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\reddy\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\reddy\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\reddy\anaconda3\lib\site-packages (from xgboost) (1.11.1)

# %%
import xgboost as xgb
model5 = xgb.XGBClassifier(random_state=1)
model5.fit(X_train, Y_train)
y_pred = model5.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
model_res.loc[len(model_res)] = ['XGBClassifier', accuracy_score(Y_test,y_pred)]
model_res
# Out:
# Accuracy Score: 0.9041666666666667
#                     Model     Score
# 0      LogisticRegression  0.875000
# 1    KNeighborsClassifier  0.872917
# 2                     SVC  0.868750
# 3  DecisionTreeClassifier  0.860417
# 4              GaussianNB  0.754167
# 5  RandomForestClassifier  0.895833
# 6           XGBClassifier  0.904167
# 7           XGBClassifier  0.904167

# %%
model_res = model_res.sort_values(by='Score', ascending=False)
model_res
# Out:
#                     Model     Score
# 6           XGBClassifier  0.904167
# 7           XGBClassifier  0.904167
# 5  RandomForestClassifier  0.895833
# 0      LogisticRegression  0.875000
# 1    KNeighborsClassifier  0.872917
# 2                     SVC  0.868750
# 3  DecisionTreeClassifier  0.860417
# 4              GaussianNB  0.754167
